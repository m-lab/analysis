# %% [markdown]
# # Basic table auditor
#
# Most of these checks can be applied to most simple MLab tables and views.
#
# This notbook is used for prototyping.  The release version is in  ../scripts/inspectTable.py

# %%
import re
import pandas as pd
import BQhelper as bq
import inspectTable

bq.project = "mlab-sandbox"

# %%
# Tests, designed to be repeated
UnitTest=True

if UnitTest:
    inspectTable.inventoryTable('measurement-lab.ndt.ndt5')
    inspectTable.inspectDataSetMappings('measurement-lab.ndt')
# Out:
# Inferred Column Mappings
#                           partition_date AS TestDate
#                   ParseInfo.TaskFileName AS fileName
#                      ParseInfo.ParseTime AS parseTime
#                      result.Control.UUID AS UUID
# Data Statistics
#                                         Total Days 300
#                                       Missing Days 0
#                                         Total Rows 1104892971
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 8022778
#                                   Duplicated UUIDs 15376
#      Top dup:ndt-hxhsf_1566008240_0000000000036A08 2
#                                      Total Servers 554
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 139
#                           Currently Active Servers 400
#                                  Total Server-days 108918
#                                Missing Server-days 861
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 1104.892971
#           slot_milli: 40199490
#       slot_milli/row: 0.03638315298867079
#      bytes processed: 152354888328
#  bytes processed/row: 137.89108296173603
#
# Table column mappings for measurement-lab.ndt.downloads
#                           partition_date AS TestDate
#                            task_filename AS fileName
#                               parse_time AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
#
# Table column mappings for measurement-lab.ndt.ndt5
#                           partition_date AS TestDate
#                   ParseInfo.TaskFileName AS fileName
#                      ParseInfo.ParseTime AS parseTime
#                      result.Control.UUID AS UUID
#
# Table column mappings for measurement-lab.ndt.recommended
#                           partition_date AS TestDate
#                            task_filename AS fileName
#                               parse_time AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
#
# Table column mappings for measurement-lab.ndt.tcpinfo
#                           partition_date AS TestDate
#                   ParseInfo.TaskFileName AS fileName
#                      ParseInfo.ParseTime AS parseTime
#                                     UUID AS UUID
#
# Table column mappings for measurement-lab.ndt.traceroute
#                           partition_date AS TestDate
#                   Parseinfo.TaskFileName AS fileName
#                      Parseinfo.ParseTime AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
#
# Table column mappings for measurement-lab.ndt.unified_downloads
#                                test_date AS TestDate
#                         "No Server Name" AS fileName
#                                     Null AS parseTime
#                                   a.UUID AS UUID
#
# Table column mappings for measurement-lab.ndt.unified_uploads
#                                test_date AS TestDate
#                         "No Server Name" AS fileName
#                                     Null AS parseTime
#                                   a.UUID AS UUID
#
# Table column mappings for measurement-lab.ndt.uploads
#                           partition_date AS TestDate
#                            task_filename AS fileName
#                               parse_time AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
#
# Table column mappings for measurement-lab.ndt.web100
#                           partition_date AS TestDate
#                            task_filename AS fileName
#                               parse_time AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID

# %%
# Expensive, but what we came for
if True:
     inspectTable.inventoryDataSet('measurement-lab.ndt')

# Expensive, but what we came for
if True:
     inspectTable.inventoryDataSet('measurement-lab.library')
# Out:
# Table Statistics for measurement-lab.ndt.downloads
# Inferred Column Mappings
#                           partition_date AS TestDate
#                            task_filename AS fileName
#                               parse_time AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
# Data Statistics
#                                         Total Days 3794
#                                       Missing Days 0
#                                         Total Rows 881446284
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 881446284
#                                   Duplicated UUIDs -1
#                                      Total Servers 511
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 16
#                           Currently Active Servers 0
#                                  Total Server-days 695413
#                                Missing Server-days 183484
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 881.446284
#           slot_milli: 117191657
#       slot_milli/row: 0.13295382728052887
#      bytes processed: 476383049376
#  bytes processed/row: 540.4561321810507
#
# Table Statistics for measurement-lab.ndt.ndt5
# Inferred Column Mappings
#                           partition_date AS TestDate
#                   ParseInfo.TaskFileName AS fileName
#                      ParseInfo.ParseTime AS parseTime
#                      result.Control.UUID AS UUID
# Data Statistics
#                                         Total Days 300
#                                       Missing Days 0
#                                         Total Rows 1104892971
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 8022778
#                                   Duplicated UUIDs 15376
#      Top dup:ndt-gt69z_1565752313_000000000001636D 2
#                                      Total Servers 554
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 139
#                           Currently Active Servers 400
#                                  Total Server-days 108918
#                                Missing Server-days 861
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 1104.892971
#           slot_milli: 38435937
#       slot_milli/row: 0.03478702282376996
#      bytes processed: 152354888328
#  bytes processed/row: 137.89108296173603
#
# Table Statistics for measurement-lab.ndt.recommended
# Inferred Column Mappings
#                           partition_date AS TestDate
#                            task_filename AS fileName
#                               parse_time AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
# Data Statistics
#                                         Total Days 3928
#                                       Missing Days 2
#                                         Total Rows 2336546392
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 2336546392
#                                   Duplicated UUIDs -1
#                                      Total Servers 514
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 19
#                           Currently Active Servers 0
#                                  Total Server-days 698634
#                                Missing Server-days 180960
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 2336.546392
#           slot_milli: 125235729
#       slot_milli/row: 0.05359864859897034
#      bytes processed: 351730230288
#  bytes processed/row: 150.5342378359248
#
# Table Statistics for measurement-lab.ndt.tcpinfo
# Inferred Column Mappings
#                           partition_date AS TestDate
#                   ParseInfo.TaskFileName AS fileName
#                      ParseInfo.ParseTime AS parseTime
#                                     UUID AS UUID
# Data Statistics
#                                         Total Days 407
#                                       Missing Days 0
#                                         Total Rows 3323622259
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 0
#                                   Duplicated UUIDs 1086950
#      Top dup:ndt-7lgjq_1583546640_0000000000000021 29
#                                      Total Servers 567
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 152
#                           Currently Active Servers 400
#                                  Total Server-days 122799
#                                Missing Server-days 1344
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 3323.622259
#           slot_milli: 633700773
#       slot_milli/row: 0.19066570254306386
#      bytes processed: 478601605296
#  bytes processed/row: 144.0
#
# Table Statistics for measurement-lab.ndt.traceroute
# Inferred Column Mappings
#                           partition_date AS TestDate
#                   Parseinfo.TaskFileName AS fileName
#                      Parseinfo.ParseTime AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
# Data Statistics
#                                         Total Days 2564
#                                       Missing Days 1
#                                         Total Rows 6141650706
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 6141650706
#                                   Duplicated UUIDs -1
#                                      Total Servers 702
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 150
#                           Currently Active Servers 402
#                                  Total Server-days 719540
#                                Missing Server-days 111223
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 6141.650706
#           slot_milli: 273853289
#       slot_milli/row: 0.04458952521224674
#      bytes processed: 684505214748
#  bytes processed/row: 111.45297046595017
#
# Table Statistics for measurement-lab.ndt.unified_downloads
# Inferred Column Mappings
#                                test_date AS TestDate
#                         "No Server Name" AS fileName
#                                     Null AS parseTime
#                                   a.UUID AS UUID
# Data Statistics
#                                         Total Days 3968
#                                       Missing Days 0
#                                         Total Rows 1286758528
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 0
#                                   Duplicated UUIDs 8695120
# Top dup:2a00:1a80:1:8::2402a02:c7f:b006:2100:9c17:85d8:5bbd:874b02018-08-29 1476
#                                      Total Servers 0
#                               Rows Missing Servers 1286758528
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 0
#                           Currently Active Servers 1
#                                  Total Server-days 3968
#                                Missing Server-days 0
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 1286.758528
#           slot_milli: 766209464
#       slot_milli/row: 0.5954570708700988
#      bytes processed: 623423403961
#  bytes processed/row: 484.49137145411635
#
# Table Statistics for measurement-lab.ndt.unified_uploads
# Inferred Column Mappings
#                                test_date AS TestDate
#                         "No Server Name" AS fileName
#                                     Null AS parseTime
#                                   a.UUID AS UUID
# Data Statistics
#                                         Total Days 4102
#                                       Missing Days 2
#                                         Total Rows 1478851829
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 0
#                                   Duplicated UUIDs 4238885
# Top dup:2001:470:1:48f::10102601:197:4400:4810:58bd:7c9a:8a3d:32d702019-01-21 1517
#                                      Total Servers 0
#                               Rows Missing Servers 1478851829
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 0
#                           Currently Active Servers 1
#                                  Total Server-days 4102
#                                Missing Server-days 2
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 1478.851829
#           slot_milli: 991940739
#       slot_milli/row: 0.6707505914711892
#      bytes processed: 471499134636
#  bytes processed/row: 318.82784021359856
#
# Table Statistics for measurement-lab.ndt.uploads
# Inferred Column Mappings
#                           partition_date AS TestDate
#                            task_filename AS fileName
#                               parse_time AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
# Data Statistics
#                                         Total Days 3928
#                                       Missing Days 2
#                                         Total Rows 1104713330
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 1104713330
#                                   Duplicated UUIDs -1
#                                      Total Servers 513
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 18
#                           Currently Active Servers 0
#                                  Total Server-days 698480
#                                Missing Server-days 181762
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 1104.71333
#           slot_milli: 122984366
#       slot_milli/row: 0.11132695031388821
#      bytes processed: 393281169984
#  bytes processed/row: 356.00291886040696
#
# Table Statistics for measurement-lab.ndt.web100
# Inferred Column Mappings
#                           partition_date AS TestDate
#                            task_filename AS fileName
#                               parse_time AS parseTime
#                 "ERROR_DISCOVERING_UUID" AS UUID
# Data Statistics
#                                         Total Days 3928
#                                       Missing Days 2
#                                         Total Rows 2596933731
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 2596933731
#                                   Duplicated UUIDs -1
#                                      Total Servers 627
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 2
#                                            Mlab4's 130
#                           Currently Active Servers 0
#                                  Total Server-days 740579
#                                Missing Server-days 87635
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 2596.933731
#           slot_milli: 112038644
#       slot_milli/row: 0.043142665776402904
#      bytes processed: 225933234597
#  bytes processed/row: 87.0
#
# Table Statistics for measurement-lab.library.ndt_unified_ndt5_downloads
# Inferred Column Mappings
#                                test_date AS TestDate
#   _internal202004.ParseInfo.TaskFileName AS fileName
#      _internal202004.ParseInfo.ParseTime AS parseTime
#                                   a.UUID AS UUID
# Data Statistics
#                                         Total Days 300
#                                       Missing Days 0
#                                         Total Rows 519170664
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 2755945
#                                   Duplicated UUIDs 8976683
#                                           Top dup: 8933489
#                                      Total Servers 554
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 139
#                           Currently Active Servers 400
#                                  Total Server-days 108809
#                                Missing Server-days 818
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 519.170664
#           slot_milli: 1228087506
#       slot_milli/row: 2.3654793908000933
#      bytes processed: 258879982288
#  bytes processed/row: 498.6413914327024
#
# Table Statistics for measurement-lab.library.ndt_unified_ndt5_uploads
# Inferred Column Mappings
#                                test_date AS TestDate
#                         "No Server Name" AS fileName
#                                     Null AS parseTime
#                                   a.UUID AS UUID
# Data Statistics
#                                         Total Days 300
#                                       Missing Days 0
#                                         Total Rows 466299631
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 1523043
#                                   Duplicated UUIDs 12560332
#                                           Top dup: 12440067
#                                      Total Servers 0
#                               Rows Missing Servers 466299631
#                              Test Servers (0t, 1t) 0
#                                            Mlab4's 0
#                           Currently Active Servers 1
#                                  Total Server-days 300
#                                Missing Server-days 0
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 466.299631
#           slot_milli: 817881833
#       slot_milli/row: 1.7539834446062428
#      bytes processed: 147319336803
#  bytes processed/row: 315.93277585716123
#
# Table Statistics for measurement-lab.library.ndt_unified_web100_downloads
# Inferred Column Mappings
#                                test_date AS TestDate
#            _internal202004.task_filename AS fileName
#               _internal202004.parse_time AS parseTime
#                                   a.UUID AS UUID
# Data Statistics
#                                         Total Days 3799
#                                       Missing Days 4
#                                         Total Rows 2020040506
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 0
#                                   Duplicated UUIDs 49515663
# Top dup:2001:438:fffd:2f::3702601:248:4100:13a0:90b9:b029:75cd:257a02019-05-04 2711
#                                      Total Servers 627
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 2
#                                            Mlab4's 130
#                           Currently Active Servers 0
#                                  Total Server-days 738317
#                                Missing Server-days 87775
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 2020.040506
#           slot_milli: 193484224
#       slot_milli/row: 0.09578234863375557
#      bytes processed: 455607579528
#  bytes processed/row: 225.5437839858841
#
# Table Statistics for measurement-lab.library.ndt_unified_web100_uploads
# Inferred Column Mappings
#                                test_date AS TestDate
#            _internal202004.task_filename AS fileName
#               _internal202004.parse_time AS parseTime
#                                   a.UUID AS UUID
# Data Statistics
#                                         Total Days 3928
#                                       Missing Days 2
#                                         Total Rows 2596933158
#             Missing UUIDs (ERROR_DISCOVERING_UUID) 0
#                                   Duplicated UUIDs 51906453
# Top dup:2001:438:fffd:2f::3702601:248:4100:13a0:90b9:b029:75cd:257a02019-05-04 2711
#                                      Total Servers 627
#                               Rows Missing Servers 0
#                              Test Servers (0t, 1t) 2
#                                            Mlab4's 130
#                           Currently Active Servers 0
#                                  Total Server-days 740579
#                                Missing Server-days 87635
#                                      End-of-Report 0
# Resource consumption
#             Rows (M): 2596.933158
#           slot_milli: 194894185
#       slot_milli/row: 0.07504782493134927
#      bytes processed: 455607579528
#  bytes processed/row: 175.44062623424674

# %%
STOP  # everything below is historical and will be deleted after the next checkin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8d78b25a4538> in <module>
# ----> 1 STOP  # everything below is historical and will be deleted after the next checkin
#
# NameError: name 'STOP' is not defined

# %%
# Infer subexpressions to access indicator columns


# Column Matcher
Patterns={
    'TestDate':[
        ('[tT]est.*[dD]ate', '{c}'),
        ('[pP]artition.*[dD]ate','{c}'),
    ],
    'fileName':[
        ('[fF]ile[nN]ame', '{c}'),
        ('.','"No Server Name"'),   # default to an unreasonable name
    ],
    'parseTime':[
        ('[pP]arse.*[tT]ime', '{c}'),
        ('.', 'Null')
    ],
    'UUID':[
        'a.UUID',
        'result.Control.UUID',
        ('UUID', '{c}'),
        ('.', '"ERROR_DISCOVERING_UUID"')  # default to an errored UUID
    ]
}

def columnMatcher(patterns, cols, verbose=False):
    
    def matchHelper(var, matches, cols, verbose):
        for m in matches:
            try:
                r, v = m
            except ValueError:  # shortcut, single item match
                if verbose:
                    print('Simple:', m)
                if m in cols:
                    return {var:m}
                continue
            if verbose:
                print ("Re:", r, v)
            for c in cols:
                if re.search(r, c):
                    return {var:v.format(c=c)}
        return {var:None}
                    
    res={}
    for var, matches in patterns.items():
        res.update({var:None})
        if verbose:
            print ('VAR:', var, matches)
        res.update(matchHelper(var, matches, cols, verbose))

    return res

if UnitTest:
    tests=['test__date', 'TestDate', 'PartitionDate', 'ParseInfo.TaskFileName' ]
    for t in tests:
        print ("   Test", t)
        print ('===  Result:', t, columnMatcher(Patterns, [t], verbose=False))


def inferColumns(table):
    return columnMatcher(Patterns, bq.getColumns(table))


mainQ="""
WITH

canonic AS (
  SELECT
    {TestDate} AS TestDate,
    REGEXP_EXTRACT({fileName}, 'mlab[1-4]-[a-z][a-z][a-z][0-9][0-9t]') AS ShortName,
    {parseTime} AS _ParseTime,
    {UUID} AS UUID,
  FROM `{fullTableName}`
),

HotUUIDs AS (
  SELECT UUID, count(*) AS cnt
  FROM canonic
  WHERE UUID NOT IN ( 'ERROR_DISCOVERING_UUID' )
  GROUP BY UUID
  ORDER BY cnt desc
  limit 1
),

ServerSet AS (
  SELECT ShortName AS _UniqueName FROM canonic GROUP BY ShortName
),

ServerDays AS (
  SELECT
    ShortName,
    DATE_DIFF(MAX(TestDate), MIN(TestDate), DAY)+1 AS cnt,
    DATE_DIFF(MAX(TestDate), MIN(TestDate), DAY)+1 - COUNT( DISTINCT TestDate) AS missing,
    MAX(TestDate) AS EndDate,
  FROM canonic
  GROUP BY ShortName
)

SELECT 10 AS seq, "Total Days" AS name, DATE_DIFF(MAX(TestDate), MIN(TestDate), DAY)+1 AS cnt FROM canonic UNION ALL
SELECT 11, "Missing Days", DATE_DIFF(MAX(TestDate), MIN(TestDate), DAY)+1 - COUNT( DISTINCT TestDate) FROM canonic UNION ALL

SELECT 20, "Total Rows", COUNT (*) FROM canonic UNION ALL
SELECT 21, "Missing UUIDs (ERROR_DISCOVERING_UUID)", COUNTIF (UUID is Null OR UUID = 'ERROR_DISCOVERING_UUID') FROM canonic UNION ALL
SELECT 22, "Duplicated UUIDs", COUNTIF(UUID IS NOT NULL AND UUID != 'ERROR_DISCOVERING_UUID') - COUNT( DISTINCT UUID ) FROM canonic UNION ALL
SELECT 23, CONCAT("Top dup:", UUID), cnt FROM HotUUIDs UNION ALL

SELECT 30, "Total Servers", COUNT ( DISTINCT ShortName ) FROM canonic UNION ALL
SELECT 31, "Rows Missing Servers", COUNTIF ( ShortName IS Null ) FROM canonic UNION ALL
SELECT 32, "Test Servers (0t, 1t)", COUNTIF ( _UniqueName like '%t' ) FROM ServerSet UNION ALL
SELECT 33, "Mlab4's", COUNTIF ( _UniqueName like 'mlab4%'  ) FROM ServerSet UNION ALL

SELECT 40, "Currently Active Servers", COUNTIF ( DATE_DIFF(CURRENT_DATE(), EndDate, DAY) < 4) FROM ServerDays UNION ALL
SELECT 41, "Total Server-days", SUM(cnt) FROM ServerDays UNION ALL
SELECT 42, "Missing Server-days", SUM(missing) FROM ServerDays UNION ALL

SELECT 99, "End-of-Report", 0.0
ORDER BY seq
"""

def inventoryTable(fullTableName):
#    project, dataset, table = fullTableName.split('.')

    print ('Inferred Column Mappings')
    expansion=inferColumns(fullTableName)
    for v, e in expansion.items():
        print ("%40s AS %s"%(e, v))
    print ('Data Statistics')
    res=bq.IndexedDataFrameQuery(mainQ, fullTableName=fullTableName, index='seq', **expansion)
    for i in res['seq']:
        print ("%50s %d"%(res['name'][i], res['cnt'][i]))

    print('Resource consumption')
    totalRows=res[res['name']=='Total Rows']['cnt'].sum()
    fmt="%20s: %s"
    print (fmt%('Rows (M)', totalRows/1000000))
    print (fmt%('slot_milli', bq.jobInfo.slot_millis))
    print (fmt%('slot_milli/row', bq.jobInfo.slot_millis/totalRows))
    print (fmt%('bytes processed', bq.jobInfo.total_bytes_processed))
    print (fmt%('bytes processed/row', bq.jobInfo.total_bytes_processed/totalRows))
    return
if UnitTest:
    ret=inventoryTable('measurement-lab.ndt.ndt5')



def inventoryDataSet(dataSet):
    tables=bq.getTables(dataSet)
    for t in tables:
        table = dataSet+'.'+t
        print('')
        print ('Table Statistics for', table)
        try:
            inventoryTable(table)
        except Exception as e:
            print ("   Crashed: ", type(e))

def inspectDataSetMappings(dataSet):
    tables=bq.getTables(dataSet)
    for t in tables:
        table = dataSet+'.'+t
        print('')
        print ('Table column mappings for', table)     
        expansion=inferColumns(table)
        for v, e in expansion.items():
            print ("%40s AS %s"%(e, v))
